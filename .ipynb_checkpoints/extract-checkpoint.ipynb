# %%
import requests
from bs4 import BeautifulSoup

from datetime import datetime
from datetime import timedelta
from time import time

import json

import pandas as pd
import numpy as np

# %% [markdown]
# # Extraction and Transformation

# %%
def get_publications(starting_date, num_days):
    '''
    Busca no Diário Oficial da União todas as RESOLUÇÕES
    da ANVISA publicadas ao longo de [num_days] dias de uma [starting_date].
    
    Retorna um dicionário de datas com listas de publicações. 
    As listas contém as seguintes informações: title, hierarchyList e url.
    
        Ex:  
        publications = {
            datetime(YYYY, mm, dd):[
                {
                'title': 'RESOLUÇÃO-RE Nº 1.341, DE 30 DE ABRIL DE 2020',
                'hierarchyList': ['Ministério da Saúde', 'Agência Nacional de Vigilância Sanitária', 'Terceira Diretoria', 'Gerência de Produtos de Higiene, Perfumes, Cosméticos e Saneantes']
                'url': 'https://www.in.gov.br/en/web/dou/-/resolucao-re-n-1.341-de-30-de-abril-de-2020-254923025'
                }, ...
            ], ...
        }
    
    [num_days] -> int
    [starting_date] -> datetime(Y, m, d) object
        
    '''
    
    url_base = r"https://www.in.gov.br/web/dou/-/"
    
    dates = [(datetime.today() - timedelta(x)).strftime('%d-%m-%Y') for x in range(num_days)]
    
    publications = {}
    for date in dates:
        
        publications[date] = []
        
        html = requests.get(r"https://www.in.gov.br/leiturajornal?data=" + date + r"&secao=do1").content
        soup = BeautifulSoup(html, 'html.parser')
        
        pubs_day = json.loads(soup.find('script', {'id':"params", 'type':'application/json'}).contents[0].replace('\n\t', ''))['jsonArray']
        
        for pub in pubs_day:
            if pub['artType'] == 'Resolução' and 'Agência Nacional de Vigilância Sanitária' in pub['hierarchyList']:
                publications[date].append({
                    'title': pub['title'],
                    'hierarchyList': pub['hierarchyList'],
                    'url': url_base + pub['urlTitle']
                })
                
    return publications

# %%
def get_data(key, publications):
    '''
    '''
    raw_data = {}
    data = []
    for date in publications:
        for pub in publications[date]:
            html = requests.get(pub['url']).content
            soup = BeautifulSoup(html, 'html.parser')
            if key in soup.get_text():
                print(pub['url'])
                required_data = soup.find_all('p', {'class':"dou-paragraph"})
                for tags in required_data:
                    data.append(tags)
                    raw_data[pub['title']] = data
    return raw_data

# %%
def split_list(lista, x): 
    #Instead of creating multiple ugly loops, I found a beautiful list comprehension.
    #So, thank to our lord and saviour Stackoverflow ༼ つ ◕_◕ ༽つ
    #https://stackoverflow.com/questions/46490348/split-a-list-with-nn-elements-into-n-lists-with-n-elements-in-every-list/46490388#46490388
    return [lista[i:i+x] for i in range(0, len(lista), x)]

def list_to_dict(lista):
    converted = {}
    for item in lista:
        key_value = item.split(': ')
        converted[key_value[0]] = key_value[1]
    return converted

# %%
def sort_by_business(lista):
    
    aimed_data = [
        'NOME DO PRODUTO E MARCA',
        'VERSÃO',
        'NUMERO DE PROCESSO',
        'NUMERO DE REGISTRO',
        'VENDA E EMPREGO',
        'VENCIMENTO',
        'APRESENTAÇÃO',
        'VALIDADE DO PRODUTO',
        'CATEGORIA',
        'ASSUNTO DA PETIÇÃO',
        'EXPEDIENTE DA PETIÇÃO'
    ]
    
    business_dict = {}
    for item in lista:
        if 'NOME DA EMPRESA:' in item:
            #Right before I change business I should split the products into separate lists
            #Here I'm also transforming each product list into a dictionary
            # Redoo this part... (ಥ﹏ಥ) Not getting every product information. Some of them are missing... 
            try:
                list_of_products = split_list(business_dict[current_business]['produtos'], 11)
                list_of_products = [list_to_dict(l) for l in list_of_products]
                business_dict[current_business]['produtos'] = list_of_products
            except:
                pass
            current_business = item.replace("NOME DA EMPRESA: ", '')
            business_dict[current_business] = {}
        elif 'AUTORIZAÇÃO' in item:
            current_business_auth = item.replace("AUTORIZAÇÃO: ", '')
            business_dict[current_business]['auth'] = current_business_auth
            business_dict[current_business]['produtos'] = []
        elif any(aimed in item for aimed in aimed_data):
            business_dict[current_business]['produtos'].append(item)
    
    return business_dict

# %%
key = 'Deferir os registros e as petições dos produtos saneantes'
starting_date = datetime(2020,6, 30)
num_days = 60

s = time()
print(f"Buscando todas as publicações dos últimos {num_days}")
pubs = get_publications(starting_date, num_days)
print(f"A busca levou {time() - s} segundos")

s = time()
print(f"Selecionando apenas as informações seguem a chave: \n \"{key}\"") 
raw_data = get_data(key, pubs)
print(f"A busca levou {time() - s} segundos")
# Out:
# Buscando todas as publicações dos últimos 60
# A busca levou 136.9777934551239 segundos
# Selecionando apenas as informações seguem a chave:
#  "Deferir os registros e as petições dos produtos saneantes"
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.821-de-16-de-julho-de-2021-332707038
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.690-de-8-de-julho-de-2021-331313194
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.585-de-1-de-julho-de-2021-329794337
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.495-de-24-de-junho-de-2021-328274955
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.404-de-17-de-junho-de-2021-326852629
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.314-de-10-de-junho-de-2021-325403737
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.186-de-2-de-junho-de-2021-323929762
# https://www.in.gov.br/web/dou/-/resolucao-re-n-2.115-de-27-de-maio-de-2021-323007247
# A busca levou 477.95988392829895 segundos

# %% [markdown]
# #### raw_data contém o corpo de todas as resolução dos meses de maio e junho. Elas ainda estão dentro das tags e em formato de texto.

# %%
clean_data = {}
for resolucao in raw_data:
    clean_data[resolucao] = [str(l).replace("</p>", '').replace("<p class=\"dou-paragraph\">", '') for l in raw_data[resolucao]]
    clean_data[resolucao] = sort_by_business(clean_data[resolucao])

# %% [markdown]
# ## Criando um DataFrame

# %%
df = pd.DataFrame(columns = [
        'RESOLUCAO',
        'EMPRESA',
        'AUTORIZACAO',
        'MARCA',
        'PROCESSO',
        'REGISTRO',
        'VENDA E EMPREGO',
        'VENCIMENTO',
        'APRESENTACAO',
        'VALIDADE PRODUTO',
        'CATEGORIA',
        'ASSUNTO PETICAO',
        'EXPEDIENTE PETICAO',
        'VERSAO'
    ])

# %%
idx = 0
e_count = 0
for resolucao in clean_data:
    for empresa in clean_data[resolucao]:
        auth = clean_data[resolucao][empresa]['auth']
        for produto in clean_data[resolucao][empresa]['produtos']:
            try:
                df.loc[idx] = [
                    resolucao, 
                    empresa, 
                    auth, 
                    produto['NOME DO PRODUTO E MARCA'],
                    produto['NUMERO DE PROCESSO'],
                    produto['NUMERO DE REGISTRO'],
                    produto['VENDA E EMPREGO'],
                    produto['VENCIMENTO'],
                    produto['APRESENTAÇÃO'],
                    produto['VALIDADE DO PRODUTO'],
                    produto['CATEGORIA'],
                    produto['ASSUNTO DA PETIÇÃO'],
                    produto['EXPEDIENTE DA PETIÇÃO'],
                    produto['VERSÃO']
                ]
                idx += 1
            except Exception as e:
                print(produto)
                e_count += 1
                print(e)
print(e_count)
# Out:
# {'NOME DO PRODUTO E MARCA': 'TEDOX PASTILHA TRICLORO', 'NUMERO DE PROCESSO': '25351.165888/2021-17', 'NUMERO DE REGISTRO': '3.6753.0024.001-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'TEDOX PASTILHA TRICLORO 200G + SACO PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205045 DESINFETANTE PARA PISCINAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# NOME DO PRODUTO E MARCA: GR 500 MASTER - DESINCRUSTANTE ALCALINO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.552547/2010-83
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0060.001-9
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 12/2025
# string indices must be integers
# APRESENTAÇÃO: BOMBONA PLASTICA + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 12 Meses
# string indices must be integers
# CATEGORIA: 3222030 DESINCRUSTANTE ALCALINO
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990630/21-9
# string indices must be integers
# NOME DO PRODUTO E MARCA: GR 500 MASTER - DESINCRUSTANTE ALCALINO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.552547/2010-83
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0060.002-7
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 12/2025
# string indices must be integers
# APRESENTAÇÃO: TAMBOR PLASTICO
# string indices must be integers
# VALIDADE DO PRODUTO: 12 Meses
# string indices must be integers
# CATEGORIA: 3222030 DESINCRUSTANTE ALCALINO
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990630/21-9
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.001-0
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: FRASCO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.002-9
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: GALAO PLASTICO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.003-7
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: BOMBONA PLASTICA
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.004-5
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: TAMBOR PLASTICO
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL-A - DETERGENTE SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.739142/2013-55
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0069.001-8
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 04/2029
# string indices must be integers
# APRESENTAÇÃO: FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 2 Meses
# string indices must be integers
# CATEGORIA: 3222045 SANITIZANTE PARA INDÚSTRIA ALIMENTÍCIA
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990541/21-6
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL-A - DETERGENTE SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.739142/2013-55
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0069.002-6
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 04/2029
# string indices must be integers
# APRESENTAÇÃO: GALAO PLASTICO
# string indices must be integers
# VALIDADE DO PRODUTO: 2 Meses
# string indices must be integers
# CATEGORIA: 3222045 SANITIZANTE PARA INDÚSTRIA ALIMENTÍCIA
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990541/21-6
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL-A - DETERGENTE SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.739142/2013-55
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0069.003-4
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 04/2029
# string indices must be integers
# APRESENTAÇÃO: BOMBONA PLASTICA OPACA
# string indices must be integers
# VALIDADE DO PRODUTO: 2 Meses
# string indices must be integers
# CATEGORIA: 3222045 SANITIZANTE PARA INDÚSTRIA ALIMENTÍCIA
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990541/21-6
# string indices must be integers
# {'NOME DO PRODUTO E MARCA': 'Biogarden - Bio Carb', 'NUMERO DE PROCESSO': '25351.011733/2021-53', 'NUMERO DE REGISTRO': '3.2068.0057.001-2', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'SACHE DE ALUMINIO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3206017 INSETICIDA DE VENDA LIVRE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'DESINFETANTE DE USO GERAL EXALIMPO', 'NUMERO DE PROCESSO': '25351.536400/2021-32', 'NUMERO DE REGISTRO': '3.3971.0001.001-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'ÚNICA + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# NOME DO PRODUTO E MARCA: NATULAR DT
# string indices must be integers
# NUMERO DE PROCESSO: 25351.266921/2014-17
# string indices must be integers
# NUMERO DE REGISTRO: 3.3727.0005.001-1
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 06/2029
# string indices must be integers
# APRESENTAÇÃO: SACO PLASTICO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 30 Meses
# string indices must be integers
# CATEGORIA: 3206025 INSETICIDA PARA EMPRESAS ESPECIALIZADAS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1931113/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: NATULAR DT
# string indices must be integers
# NUMERO DE PROCESSO: 25351.266921/2014-17
# string indices must be integers
# NUMERO DE REGISTRO: 3.3727.0005.002-1
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 06/2029
# string indices must be integers
# APRESENTAÇÃO: BLISTES + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 30 Meses
# string indices must be integers
# CATEGORIA: 3206025 INSETICIDA PARA EMPRESAS ESPECIALIZADAS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1931113/21-1
# string indices must be integers
# {'NOME DO PRODUTO E MARCA': 'Cleanner BIO 3000', 'NUMERO DE PROCESSO': '25351.866943/2020-09', 'NUMERO DE REGISTRO': '3.3077.0023.001-1', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'BIO 3000 + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3103084 DESENGRAXANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.3077.0023.003-6', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'BIO 3000 + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3103084 DESENGRAXANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Cleanner BIO 3000', 'NUMERO DE PROCESSO': '25351.866943/2020-09'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'BIO 3000 + TAMBOR PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3103084 DESENGRAXANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'FIPROTECH', 'NUMERO DE PROCESSO': '25351.541599/2021-11', 'NUMERO DE REGISTRO': '3.2233.0120.001-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'SACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '36 Meses', 'CATEGORIA': '3206017 INSETICIDA DE VENDA LIVRE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'DELLA-ACID', 'NUMERO DE PROCESSO': '25351.632699/2013-22', 'NUMERO DE REGISTRO': '3.5569.0005.001-6', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '02/2029', 'APRESENTAÇÃO': 'BOMBONA PLASTICA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222029 DESINCRUSTANTE ÁCIDO', 'ASSUNTO DA PETIÇÃO': '392 REG. SANEANTES - Novo Prazo de Validade de Produto', 'EXPEDIENTE DA PETIÇÃO': '1743590/21-1'}
# 'VERSÃO'
# {'NUMERO DE PROCESSO': '25351.632699/2013-22', 'NUMERO DE REGISTRO': '3.5569.0005.002-4', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '02/2029', 'APRESENTAÇÃO': 'GALAO PLASTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222029 DESINCRUSTANTE ÁCIDO', 'ASSUNTO DA PETIÇÃO': '392 REG. SANEANTES - Novo Prazo de Validade de Produto', 'EXPEDIENTE DA PETIÇÃO': '1743590/21-1', 'NOME DO PRODUTO E MARCA': 'DELLA-ACID'}
# 'VERSÃO'
# {'NUMERO DE REGISTRO': '3.5569.0005.003-2', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '02/2029', 'APRESENTAÇÃO': 'TAMBOR PLASTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222029 DESINCRUSTANTE ÁCIDO', 'ASSUNTO DA PETIÇÃO': '392 REG. SANEANTES - Novo Prazo de Validade de Produto', 'EXPEDIENTE DA PETIÇÃO': '1743590/21-1'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'DETERGRILL DETERGENTE DESENGORDURANTE ALCALINO - DETERFORT', 'NUMERO DE PROCESSO': '25351.075861/2021-25', 'NUMERO DE REGISTRO': '3.3219.0024.001-4', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3211042 DETERGENTE DESENGORDURANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.3219.0024.003-0', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'BOMBONA PLASTICA OPACA + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3211042 DETERGENTE DESENGORDURANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'DETERGRILL DETERGENTE DESENGORDURANTE ALCALINO - DETERFORT', 'NUMERO DE PROCESSO': '25351.075861/2021-25'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3211042 DETERGENTE DESENGORDURANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# NOME DO PRODUTO E MARCA: Alpha HP Wipes
# string indices must be integers
# NUMERO DE PROCESSO: 25351.462887/2021-18
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0299.001-1
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 07/2031
# string indices must be integers
# APRESENTAÇÃO: Única + BALDE + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: Alpha HP Wipes
# string indices must be integers
# NUMERO DE PROCESSO: 25351.462887/2021-18
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0299.002-8
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 07/2031
# string indices must be integers
# APRESENTAÇÃO: Única + POTE DE PLASTICO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: Alpha HP Wipes
# string indices must be integers
# NUMERO DE PROCESSO: 25351.462887/2021-18
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0299.003-6
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 07/2031
# string indices must be integers
# APRESENTAÇÃO: Única + SACHET + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: Alpha HP Wipes
# string indices must be integers
# NUMERO DE PROCESSO: 25351.462887/2021-18
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0299.004-4
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 07/2031
# string indices must be integers
# APRESENTAÇÃO: Única + SACO PLASTICO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: OXIVIR 1 WIPES
# string indices must be integers
# NUMERO DE PROCESSO: 25351.704597/2020-68
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0297.001-9
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 12/2030
# string indices must be integers
# APRESENTAÇÃO: BALDE
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1622670/21-3
# string indices must be integers
# NOME DO PRODUTO E MARCA: OXIVIR 1 WIPES
# string indices must be integers
# NUMERO DE PROCESSO: 25351.704597/2020-68
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0297.002-7
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 12/2030
# string indices must be integers
# APRESENTAÇÃO: POTE
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1622670/21-3
# string indices must be integers
# NOME DO PRODUTO E MARCA: OXIVIR 1 WIPES
# string indices must be integers
# NUMERO DE PROCESSO: 25351.704597/2020-68
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0297.003-5
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 12/2030
# string indices must be integers
# APRESENTAÇÃO: SACHET
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1622670/21-3
# string indices must be integers
# NOME DO PRODUTO E MARCA: OXIVIR 1 WIPES
# string indices must be integers
# NUMERO DE PROCESSO: 25351.704597/2020-68
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0297.004-3
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 12/2030
# string indices must be integers
# APRESENTAÇÃO: SACO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1622670/21-3
# string indices must be integers
# NOME DO PRODUTO E MARCA: OXIVIR 1 WIPES
# string indices must be integers
# NUMERO DE PROCESSO: 25351.704597/2020-68
# string indices must be integers
# NUMERO DE REGISTRO: 3.2661.0297.005-1
# string indices must be integers
# VENDA E EMPREGO:
# string indices must be integers
# VENCIMENTO: 12/2030
# string indices must be integers
# APRESENTAÇÃO: SACO PLASTICO REFIL
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 396 REG. SANEANTES - Alteração (Inclusão Ou Exclusão) de Fabricante
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1622670/21-3
# string indices must be integers
# {'NOME DO PRODUTO E MARCA': 'ENFORCE LP', 'NUMERO DE PROCESSO': '25351.074198/2005-21', 'NUMERO DE REGISTRO': '3.0053.0704.002-7', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '03/2030', 'APRESENTAÇÃO': 'SACO PLASTICO + BALDE', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3222030 DESINCRUSTANTE ALCALINO', 'ASSUNTO DA PETIÇÃO': '332 REG. SANEANTES - Nova Embalagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '3894345/20-9'}
# 'VERSÃO'
# {'NUMERO DE PROCESSO': '25351.131177/2021-31', 'NUMERO DE REGISTRO': '3.0053.0923.002-8', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'UNICA + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '4300213 DETERGENTE PARA USO ESPECÍFICO', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'ENFORCE LP'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'UNICA + TAMBOR PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '4300213 DETERGENTE PARA USO ESPECÍFICO', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'ENFORCE LP', 'NUMERO DE PROCESSO': '25351.131177/2021-31', 'NUMERO DE REGISTRO': '3.0053.0923.003-6'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'APRESENTAÇÃO': 'UNICA + ACONDICIONAMENTO NAO PREVISTO NA TABELA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '4300213 DETERGENTE PARA USO ESPECÍFICO', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'MASTER RUST', 'NUMERO DE PROCESSO': '25351.564123/2021-58', 'NUMERO DE REGISTRO': '3.4145.0072.001-2', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222040 TIRA MANCHAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.4145.0072.003-9', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222040 TIRA MANCHAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'MASTER RUST', 'NUMERO DE PROCESSO': '25351.564123/2021-58'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'TAMBOR PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222040 TIRA MANCHAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'MASTER RUST', 'NUMERO DE PROCESSO': '25351.564123/2021-58', 'NUMERO DE REGISTRO': '3.4145.0072.004-7', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222040 TIRA MANCHAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'ENZYFOUR', 'NUMERO DE PROCESSO': '25351.661659/2013-28', 'NUMERO DE REGISTRO': '3.2154.0014.001-1', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '03/2029', 'APRESENTAÇÃO': 'FRASCO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222020 DETERGENTE ENZIMÁTICO', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '1744932/21-2'}
# 'VERSÃO'
# {'NUMERO DE PROCESSO': '25351.661659/2013-28', 'NUMERO DE REGISTRO': '3.2154.0014.002-8', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '03/2029', 'APRESENTAÇÃO': 'BOMBONA PLASTICA + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222020 DETERGENTE ENZIMÁTICO', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '1744932/21-2'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'ZLAV 02 LÍQUID ADITIVO ALCALINO', 'NUMERO DE PROCESSO': '25351.474577/2020-57', 'NUMERO DE REGISTRO': '3.7087.0008.001-1', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'ZLAV 02 LÍQUID ADITIVO ALCALINO + BOMBONA PLASTICA OPACA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222039 LAVA ROUPAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'ÁGUA SANITÁRIA ECO', 'NUMERO DE PROCESSO': '25351.907638/2021-57', 'NUMERO DE REGISTRO': '3.5232.0003.001-6', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'GALÃO PLASTICA OPACA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '3103033 ÁGUA SANITÁRIA', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.5232.0003.002-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '3103033 ÁGUA SANITÁRIA', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.001-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Marine + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.8674.0001.003-6', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Marine + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Tutti-Frutti + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.004-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.005-2', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Tutti-Frutti + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.006-0', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Tutti-Frutti + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.008-7', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Lavanda + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Lavanda + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.009-5'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'APRESENTAÇÃO': 'Floral + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.010-9', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.011-7', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Floral + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.012-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Floral + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.8674.0001.014-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Eucalipto + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Eucalipto + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.015-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.016-8', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Pindorama + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'Toilet Bus Desinfetante Fokus', 'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.017-6', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Pindorama + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE PROCESSO': '25351.940520/2020-50', 'NUMERO DE REGISTRO': '3.8674.0001.018-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'Pindorama + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'GÁVEA G-200 INOX', 'NUMERO DE PROCESSO': '25351.895950/2021-91', 'NUMERO DE REGISTRO': '3.4568.0020.001-1', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'GALAO PLÁSTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3203018 DETERGENTE PROFISSIONAL DESINCRUSTANTE ÁCIDO', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'MAMI IODO 10.000', 'NUMERO DE PROCESSO': '25351.160090/2021-71', 'NUMERO DE REGISTRO': '3.1685.0006.001-2', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'VERSÃO 1 + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.1685.0006.003-9', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'VERSÃO 1 + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'MAMI IODO 10.000', 'NUMERO DE PROCESSO': '25351.160090/2021-71'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'VERSÃO 1 + TAMBOR PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'MAMI IODO 10.000', 'NUMERO DE PROCESSO': '25351.160090/2021-71', 'NUMERO DE REGISTRO': '3.1685.0006.004-7', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'ÁGUA SANITÁRIA YLÁ', 'NUMERO DE PROCESSO': '25351.369169/2021-65', 'NUMERO DE REGISTRO': '3.9715.0001.001-6', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'GALÃO PLÁSTICO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '3103033 ÁGUA SANITÁRIA', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.9715.0001.002-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '6 Meses', 'CATEGORIA': '3103033 ÁGUA SANITÁRIA', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'G5 100 - Alvejante Peracético', 'NUMERO DE PROCESSO': '25351.098668/2021-62', 'NUMERO DE REGISTRO': '3.8727.0025.001-2', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'ÚNICA + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3102017 ALVEJANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.8727.0025.002-0', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'ÚNICA + ACONDICIONAMENTO NAO PREVISTO NA TABELA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3102017 ALVEJANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'ÁLCOOL 70º ILLO QUÍMICA', 'NUMERO DE PROCESSO': '25351.253862/2021-17', 'NUMERO DE REGISTRO': '3.4251.0007.001-6', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2031', 'APRESENTAÇÃO': 'FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'CLORO EM CRISTAIS QBOA', 'NUMERO DE PROCESSO': '25351.225887/2020-40', 'NUMERO DE REGISTRO': '3.1940.0042.001-9', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'Cloro em Cristais Qboa + FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '2012815/21-9'}
# 'VERSÃO'
# {'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.001-8', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'FLORAL DESOLIM + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.9381.0014.003-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'FLORAL DESOLIM + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'FRESH + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.004-2', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.005-0', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'FRESH + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.006-9', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'FRESH + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.008-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'HERBAL + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'HERBAL + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.009-3'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'APRESENTAÇÃO': 'LAVANDA + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.010-7', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.011-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'LAVANDA + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.012-3', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'LAVANDA + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.9381.0014.014-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'RELAX MELISSA + FRASCO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'RELAX MELISSA + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'INFINITY BAC ULTRA', 'NUMERO DE PROCESSO': '25351.456199/2020-20', 'NUMERO DE REGISTRO': '3.9381.0014.015-8', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE,PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'INSETICIDA E ACARICIDA - SPURION', 'NUMERO DE PROCESSO': '25351.315536/2010-15', 'NUMERO DE REGISTRO': '3.2781.0028.001-9', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '07/2030', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '2 Ano(s)', 'CATEGORIA': '3206025 INSETICIDA PARA EMPRESAS ESPECIALIZADAS', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '0954404/21-1'}
# 'VERSÃO'
# {'NOME DO PRODUTO E MARCA': 'PRATT DETERGENTE CLORADO', 'NUMERO DE PROCESSO': '25351.034615/2021-13', 'NUMERO DE REGISTRO': '3.3701.0003.001-3', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'PRATT DETERGENTE CLORADO + BOMBONA PLASTICA + BANDEJA DE PAPELAO COM INVOLUCRO PLASTICO', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3211042 DETERGENTE DESENGORDURANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.3701.0003.002-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'PRATT DETERGENTE CLORADO + BOMBONA PLASTICA + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '12 Meses', 'CATEGORIA': '3211042 DETERGENTE DESENGORDURANTE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'REMOVEDOR REMOVE FÁCIL KITLAR', 'NUMERO DE PROCESSO': '25351.226490/2017-09', 'NUMERO DE REGISTRO': '3.5248.0004.001-0', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '03/2028', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO OPACO + FILME PLASTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3202038 REMOVEDOR', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '2004658/21-5'}
# 'VERSÃO'
# {'NUMERO DE PROCESSO': '25351.766439/2018-87', 'NUMERO DE REGISTRO': '3.5248.0004.002-9', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '03/2028', 'APRESENTAÇÃO': 'GALAO PLASTICO + FILME PLASTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3202038 REMOVEDOR', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '2004658/21-5', 'NOME DO PRODUTO E MARCA': 'CLORO LIQUIDO KITLAR'}
# 'VERSÃO'
# ...
# 'VERSÃO'
# {'CATEGORIA': '3205053 DESINFETANTE PARA INDÚSTRIA ALIMENTÍCIA E AFINS', 'ASSUNTO DA PETIÇÃO': '389 REG. SANEANTES - Alteração de Rotulagem de Produto', 'EXPEDIENTE DA PETIÇÃO': '1021032/21-2'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'LIMPA PISOS QUALITY', 'NUMERO DE PROCESSO': '25351.109633/2021-66', 'NUMERO DE REGISTRO': '3.3981.0004.001-9', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'LIMPA PISOS QUALITY + FRASCO DE PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222033 LIMPA PISOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.3981.0004.003-5', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'LIMPA PISOS QUALITY + BOMBONA PLASTICA OPACA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222033 LIMPA PISOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'LIMPA PISOS QUALITY', 'NUMERO DE PROCESSO': '25351.109633/2021-66'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'LIMPA PISOS QUALITY + BOMBONA PLASTICA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3222033 LIMPA PISOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'DESINFETANTE QUIMIBEL', 'NUMERO DE PROCESSO': '25351.071492/2020-11', 'NUMERO DE REGISTRO': '3.2727.0005.001-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'DESINFETANTE QUIMIBEL + FRASCO DE PLÁSTICO TRANSLÚCIDO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.2727.0005.002-3', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'DESINFETANTE QUIMIBEL + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'KI-RATO', 'NUMERO DE PROCESSO': '25351.907625/2021-88', 'NUMERO DE REGISTRO': '3.3554.0036.001-5', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'SACHE DE PAPEL + SACO PLASTICO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3207013 RATICIDA DE VENDA LIVRE', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NOME DO PRODUTO E MARCA': 'ÁLCOOL 70º RILLO', 'NUMERO DE PROCESSO': '25351.919786/2021-14', 'NUMERO DE REGISTRO': '3.2944.0008.001-7', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'FRASCO DE PLASTICO TRANSPARENTE + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.2944.0008.002-5', 'VENDA E EMPREGO': 'PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205029 DESINFETANTE HOSPITALAR PARA SUPERFÍCIES FIXAS E ARTIGOS NÃO CRÍTICOS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'CB 100-BAC', 'NUMERO DE PROCESSO': '25351.315983/2020-89', 'NUMERO DE REGISTRO': '3.4754.0019.001-3', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'CB 100-BAC + FRASCO DE PLÁSTICO TRANSLÚCIDO COM GATILHO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'NUMERO DE REGISTRO': '3.4754.0019.003-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'CB 100-BAC + GALAO PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'CB 100-BAC', 'NUMERO DE PROCESSO': '25351.315983/2020-89'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'CB 100-BAC + TAMBOR PLASTICO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'CB 100-BAC', 'NUMERO DE PROCESSO': '25351.315983/2020-89', 'NUMERO DE REGISTRO': '3.4754.0019.004-8', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes', 'NOME DO PRODUTO E MARCA': 'CB 100-BAC', 'NUMERO DE PROCESSO': '25351.315983/2020-89', 'NUMERO DE REGISTRO': '3.4754.0019.005-6', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '05/2031', 'APRESENTAÇÃO': 'CB 100-BAC + POTE DE PLASTICO OPACO + CAIXA DE PAPELAO'}
# 'EXPEDIENTE DA PETIÇÃO'
# {'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'NOME DO PRODUTO E MARCA'
# {'NOME DO PRODUTO E MARCA': 'ÁLCOOL EM GEL WALTRICK', 'NUMERO DE PROCESSO': '25351.100136/2020-11', 'NUMERO DE REGISTRO': '3.8561.0002.001-4', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '01/2031', 'APRESENTAÇÃO': 'ÁLCOOL GEL WALTRICK. FRASCO DE PLÁSTICO OPACO + PRODUTO CONTÉM SOMENTE EMBALAGEM PRIMÁRIA', 'VALIDADE DO PRODUTO': '1 Ano(s)', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '3782 REG. SANEANTES - Retificação de Publicação de Registro', 'EXPEDIENTE DA PETIÇÃO': '1039501/21-4'}
# 'VERSÃO'
# {'NUMERO DE PROCESSO': '25351.100136/2020-11', 'NUMERO DE REGISTRO': '3.8561.0002.002-2', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '01/2031', 'APRESENTAÇÃO': 'ÁLCOOL GEL WALTRICK. BOMBONA PLASTICA OPACA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA', 'VALIDADE DO PRODUTO': '1 Ano(s)', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '3782 REG. SANEANTES - Retificação de Publicação de Registro', 'EXPEDIENTE DA PETIÇÃO': '1039501/21-4', 'NOME DO PRODUTO E MARCA': 'ÁLCOOL EM GEL WALTRICK'}
# 'VERSÃO'
# {'NUMERO DE REGISTRO': '3.8561.0002.003-0', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '01/2031', 'APRESENTAÇÃO': 'ÁLCOOL GEL WALTRICK. FRASCO DE PLÁSTICO TRANSLÚCIDO. PRODUTO CONTÉM SOMENTE EMBALAGEM PRIMÁRIA', 'VALIDADE DO PRODUTO': '1 Ano(s)', 'CATEGORIA': '3205061 DESINFETANTE PARA USO GERAL', 'ASSUNTO DA PETIÇÃO': '3782 REG. SANEANTES - Retificação de Publicação de Registro', 'EXPEDIENTE DA PETIÇÃO': '1039501/21-4'}
# 'NOME DO PRODUTO E MARCA'
# NOME DO PRODUTO E MARCA: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN
# string indices must be integers
# NUMERO DE PROCESSO: 25351.034348/2021-84
# string indices must be integers
# NUMERO DE REGISTRO: 3.5990.0004.001-8
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 05/2031
# string indices must be integers
# APRESENTAÇÃO: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN + CAIXA DE PAPELAO + FRASCO DE PLASTICO TRANSPARENTE
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN
# string indices must be integers
# NUMERO DE PROCESSO: 25351.034348/2021-84
# string indices must be integers
# NUMERO DE REGISTRO: 3.5990.0004.002-6
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 05/2031
# string indices must be integers
# APRESENTAÇÃO: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN + CAIXA DE PAPELAO + FRASCO DE PLÁSTICO TRANSLÚCIDO
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN
# string indices must be integers
# NUMERO DE PROCESSO: 25351.034348/2021-84
# string indices must be integers
# NUMERO DE REGISTRO: 3.5990.0004.003-4
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 05/2031
# string indices must be integers
# APRESENTAÇÃO: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN + BOMBONA PLASTICA OPACA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN
# string indices must be integers
# NUMERO DE PROCESSO: 25351.034348/2021-84
# string indices must be integers
# NUMERO DE REGISTRO: 3.5990.0004.004-2
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 05/2031
# string indices must be integers
# APRESENTAÇÃO: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN + TAMBOR PLASTICO OPACO + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# NOME DO PRODUTO E MARCA: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN
# string indices must be integers
# NUMERO DE PROCESSO: 25351.034348/2021-84
# string indices must be integers
# NUMERO DE REGISTRO: 3.5990.0004.005-0
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 05/2031
# string indices must be integers
# APRESENTAÇÃO: DESINFETANTE HOSPITALAR BAC 640 H WHITE CLEAN + ACONDICIONAMENTO NAO PREVISTO NA TABELA + PRODUTO SOMENTE CONTEM EMBALAGEM PRIMARIA
# string indices must be integers
# VALIDADE DO PRODUTO: 24 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 30020 REG. SANEANTES - Registro de produtos saneantes
# string indices must be integers
# {'NOME DO PRODUTO E MARCA': 'TEDOX PASTILHA TRICLORO', 'NUMERO DE PROCESSO': '25351.165888/2021-17', 'NUMERO DE REGISTRO': '3.6753.0024.001-1', 'VENDA E EMPREGO': 'PRODUTO DE VENDA LIVRE', 'VENCIMENTO': '06/2031', 'APRESENTAÇÃO': 'TEDOX PASTILHA TRICLORO 200G + SACO PLASTICO OPACO + CAIXA DE PAPELAO', 'VALIDADE DO PRODUTO': '24 Meses', 'CATEGORIA': '3205045 DESINFETANTE PARA PISCINAS', 'ASSUNTO DA PETIÇÃO': '30020 REG. SANEANTES - Registro de produtos saneantes'}
# 'EXPEDIENTE DA PETIÇÃO'
# NOME DO PRODUTO E MARCA: GR 500 MASTER - DESINCRUSTANTE ALCALINO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.552547/2010-83
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0060.001-9
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 12/2025
# string indices must be integers
# APRESENTAÇÃO: BOMBONA PLASTICA + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 12 Meses
# string indices must be integers
# CATEGORIA: 3222030 DESINCRUSTANTE ALCALINO
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990630/21-9
# string indices must be integers
# NOME DO PRODUTO E MARCA: GR 500 MASTER - DESINCRUSTANTE ALCALINO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.552547/2010-83
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0060.002-7
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE USO PROFISSIONAL OU DE VENDA RESTRITA
# string indices must be integers
# VENCIMENTO: 12/2025
# string indices must be integers
# APRESENTAÇÃO: TAMBOR PLASTICO
# string indices must be integers
# VALIDADE DO PRODUTO: 12 Meses
# string indices must be integers
# CATEGORIA: 3222030 DESINCRUSTANTE ALCALINO
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990630/21-9
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.001-0
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: FRASCO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.002-9
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: GALAO PLASTICO + CAIXA DE PAPELAO
# string indices must be integers
# VALIDADE DO PRODUTO: 4 Meses
# string indices must be integers
# CATEGORIA: 3205061 DESINFETANTE PARA USO GERAL
# string indices must be integers
# ASSUNTO DA PETIÇÃO: 389 REG. SANEANTES - Alteração de Rotulagem de Produto
# string indices must be integers
# EXPEDIENTE DA PETIÇÃO: 1990334/21-1
# string indices must be integers
# NOME DO PRODUTO E MARCA: ATLABIO CL SANITIZANTE ALCALINO CLORADO
# string indices must be integers
# NUMERO DE PROCESSO: 25351.689953/2008-10
# string indices must be integers
# NUMERO DE REGISTRO: 3.1908.0042.003-7
# string indices must be integers
# VENDA E EMPREGO: PRODUTO DE VENDA LIVRE
# string indices must be integers
# VENCIMENTO: 01/2029
# string indices must be integers
# APRESENTAÇÃO: BOMBONA PLASTICA
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df
# Out:
#                                           RESOLUCAO  \
# 0     RESOLUÇÃO RE Nº 2.821, DE 16 DE Julho DE 2021
# 1     RESOLUÇÃO RE Nº 2.821, DE 16 DE Julho DE 2021
# 2     RESOLUÇÃO RE Nº 2.821, DE 16 DE Julho DE 2021
# 3     RESOLUÇÃO RE Nº 2.821, DE 16 DE Julho DE 2021
# 4     RESOLUÇÃO RE Nº 2.821, DE 16 DE Julho DE 2021
# ...                                             ...
# 1803   RESOLUÇÃO RE Nº 2.115, DE 27 DE Maio DE 2021
# 1804   RESOLUÇÃO RE Nº 2.115, DE 27 DE Maio DE 2021
# 1805   RESOLUÇÃO RE Nº 2.115, DE 27 DE Maio DE 2021
# 1806   RESOLUÇÃO RE Nº 2.115, DE 27 DE Maio DE 2021
# 1807   RESOLUÇÃO RE Nº 2.115, DE 27 DE Maio DE 2021
#
#                              EMPRESA AUTORIZACAO                        MARCA  \
# 0     Archote Indústria Química Ltda   3.00524-6  DIA% DESINFETANTE USO GERAL
# 1     Archote Indústria Química Ltda   3.00524-6  DIA% DESINFETANTE USO GERAL
# 2     Archote Indústria Química Ltda   3.00524-6  DIA% DESINFETANTE USO GERAL
# 3     Archote Indústria Química Ltda   3.00524-6  DIA% DESINFETANTE USO GERAL
# 4     Archote Indústria Química Ltda   3.00524-6  DIA% DESINFETANTE USO GERAL
# ...                              ...         ...                          ...
# 1803  TEIÚ INDÚSTRIA E COMÉRCIO LTDA   3.01428-1            DESINFETANTE TEIÚ
# 1804  TEIÚ INDÚSTRIA E COMÉRCIO LTDA   3.01428-1            DESINFETANTE TEIÚ
# 1805  TEIÚ INDÚSTRIA E COMÉRCIO LTDA   3.01428-1            DESINFETANTE TEIÚ
# 1806  TEIÚ INDÚSTRIA E COMÉRCIO LTDA   3.01428-1            DESINFETANTE TEIÚ
# 1807  TEIÚ INDÚSTRIA E COMÉRCIO LTDA   3.01428-1            DESINFETANTE TEIÚ
#
#                   PROCESSO           REGISTRO         VENDA E EMPREGO  \
# 0     25351.704205/2017-65  3.0524.0040.001-3  PRODUTO DE VENDA LIVRE
# 1     25351.704205/2017-65  3.0524.0040.002-1  PRODUTO DE VENDA LIVRE
# 2     25351.704205/2017-65  3.0524.0040.003-1  PRODUTO DE VENDA LIVRE
# 3     25351.704205/2017-65  3.0524.0040.004-8  PRODUTO DE VENDA LIVRE
# 4     25351.704205/2017-65  3.0524.0040.005-6  PRODUTO DE VENDA LIVRE
# ...                    ...                ...                     ...
# 1803  25351.903336/2016-71  3.1428.0019.014-7  PRODUTO DE VENDA LIVRE
# 1804  25351.903336/2016-71  3.1428.0019.015-5  PRODUTO DE VENDA LIVRE
# 1805  25351.903336/2016-71  3.1428.0019.016-3  PRODUTO DE VENDA LIVRE
# 1806  25351.903336/2016-71  3.1428.0019.017-1  PRODUTO DE VENDA LIVRE
# 1807  25351.903336/2016-71  3.1428.0019.018-1  PRODUTO DE VENDA LIVRE
#
#      VENCIMENTO                                       APRESENTACAO  \
# 0       03/2028                    FRASCO DE PLASTICO TRANSPARENTE
# 1       03/2028                                     GALAO PLASTICO
# 2       03/2028                    FRASCO DE PLASTICO TRANSPARENTE
# 3       03/2028                                     GALAO PLASTICO
# 4       03/2028                    FRASCO DE PLASTICO TRANSPARENTE
# ...         ...                                                ...
# 1803    03/2026        FRASCO DE PLASTICO OPACO + CAIXA DE PAPELAO
# 1804    03/2026          BOMBONA PLASTICA OPACA + CAIXA DE PAPELAO
# 1805    03/2026  FRASCO DE PLASTICO TRANSPARENTE + CAIXA DE PAP...
# 1806    03/2026  FRASCO DE PLASTICO TRANSPARENTE + CAIXA DE PAP...
# 1807    03/2026  FRASCO DE PLASTICO TRANSPARENTE + CAIXA DE PAP...
#
#      VALIDADE PRODUTO                            CATEGORIA  \
# 0            24 Meses  3205061 DESINFETANTE PARA USO GERAL
# 1            24 Meses  3205061 DESINFETANTE PARA USO GERAL
# 2            24 Meses  3205061 DESINFETANTE PARA USO GERAL
# 3            24 Meses  3205061 DESINFETANTE PARA USO GERAL
# 4            24 Meses  3205061 DESINFETANTE PARA USO GERAL
# ...               ...                                  ...
# 1803         2 Ano(s)  3205061 DESINFETANTE PARA USO GERAL
# 1804         2 Ano(s)  3205061 DESINFETANTE PARA USO GERAL
# 1805         2 Ano(s)  3205061 DESINFETANTE PARA USO GERAL
# 1806         2 Ano(s)  3205061 DESINFETANTE PARA USO GERAL
# 1807         2 Ano(s)  3205061 DESINFETANTE PARA USO GERAL
#
#                                         ASSUNTO PETICAO EXPEDIENTE PETICAO  \
# 0     389 REG. SANEANTES - Alteração de Rotulagem de...       1897959/21-4
# 1     389 REG. SANEANTES - Alteração de Rotulagem de...       1897959/21-4
# 2     389 REG. SANEANTES - Alteração de Rotulagem de...       1897959/21-4
# 3     389 REG. SANEANTES - Alteração de Rotulagem de...       1897959/21-4
# 4     389 REG. SANEANTES - Alteração de Rotulagem de...       1897959/21-4
# ...                                                 ...                ...
# 1803  389 REG. SANEANTES - Alteração de Rotulagem de...       1168766/21-4
# 1804  389 REG. SANEANTES - Alteração de Rotulagem de...       1168766/21-4
# 1805  389 REG. SANEANTES - Alteração de Rotulagem de...       1168766/21-4
# 1806  389 REG. SANEANTES - Alteração de Rotulagem de...       1168766/21-4
# 1807  389 REG. SANEANTES - Alteração de Rotulagem de...       1168766/21-4
#
#                  VERSAO
# 0             EUCALIPTO
# 1             EUCALIPTO
# 2                 PINHO
# 3                 PINHO
# 4               LAVANDA
# ...                 ...
# 1803             FLORAL
# 1804             FLORAL
# 1805      PINHO LAVANDA
# 1806       PINHO CITRUS
# 1807  PINHO TRADICIONAL
#
# [1808 rows x 14 columns]
